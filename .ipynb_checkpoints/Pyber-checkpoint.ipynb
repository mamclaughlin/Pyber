# %% [markdown]
# # PyPlot

# %%
# import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import files
file = "./Resources/city_data.csv"
file2 = "./Resources/ride_data.csv"

# %%
# Merged files
city_data = pd.read_csv(file)
ride_data = pd.read_csv(file2)

combined_df = pd.merge(city_data, ride_data, how='outer', on='city')
combined_df.head()

# group by city name ------------
city_info = combined_df.groupby("city").sum()
city_name = combined_df["city"].unique()

# ride count --------------- FIX
rider_count = combined_df.groupby("city").count()
# city_info["ride_id"]

# average fare count -----------------
fare_count = city_info["fare"]/rider_count["ride_id"]

# driver count --------------
drivers = city_info["driver_count"]

# Variables for plots:
city = sorted(city_name)
ride_count = [x for x in rider_count]
# avg_fare = [x for x in fare_count]
driver_count = [x for x in drivers]

fare = fare_count.to_frame()
fare.columns = ["fare"]

# urban, suburban, rural -----
city_area = combined_df.groupby(["city","type"]).count()

# city_area.index.get_level_values("type")

bubble_info = pd.DataFrame(
        {   "City": [x for x in sorted(city_name)],
            "Ride Count": [x for x in rider_count["ride_id"]],
            "Average Fare": [x for x in fare["fare"]],
            "Driver Count": [x for x in drivers],
            "Area": [x for x in city_area.index.get_level_values("type")]
        }
    )
bubble_info[["City","Ride Count", "Average Fare", "Driver Count","Area"]]

new_bubble_info = bubble_info.set_index(['City'])

del new_bubble_info.index.name
new_bubble_info
# Out:
#                           Area  Average Fare  Driver Count  Ride Count
# Alvarezhaven             Urban     23.928710           651          31
# Alyssaberg               Urban     20.609615          1742          26
# Anitamouth            Suburban     37.315556           144           9
# Antoniomouth             Urban     23.625000           462          22
# Aprilchester             Urban     21.981579           931          19
# Arnoldview               Urban     25.106452          1271          31
# Campbellport          Suburban     33.711333           390          15
# Carrollbury           Suburban     36.606000            40          10
# Carrollfort              Urban     25.395517          1595          29
# Clarkstad             Suburban     31.051667           252          12
# Conwaymouth           Suburban     34.591818           198          11
# Davidtown                Urban     22.978095          1533          21
# Davistown                Urban     21.497200           625          25
# East Cherylfurt       Suburban     31.416154           117          13
# East Douglas             Urban     26.169091           264          22
# East Erin                Urban     24.478214          1204          28
# East Jenniferchester  Suburban     32.599474           418          19
# East Leslie              Rural     33.660909            99          11
# East Stephen             Rural     39.053000            60          10
# East Troybury            Rural     33.244286            21           7
# Edwardsbury              Urban     26.876667           297          27
# Erikport                 Rural     30.043750            24           8
# Eriktown                 Urban     25.478947           285          19
# Floresberg            Suburban     32.310000            70          10
# Fosterside               Urban     23.034583          1656          24
# Hernandezshire           Rural     32.002222            90           9
# Horneland                Rural     21.482500            32           4
# Jacksonfort              Rural     32.006667            36           6
# Jacobfort                Urban     24.779355          1612          31
# Jasonfort             Suburban     27.831667           300          12
# ...                        ...           ...           ...         ...
# South Roy                Urban     26.031364           770          22
# South Shannonborough  Suburban     26.516667           135          15
# Spencertown              Urban     23.681154          1768          26
# Stevensport              Rural     31.948000            30           5
# Stewartview              Urban     21.614000          1470          30
# Swansonbury              Urban     27.464706          2176          34
# Thomastown            Suburban     30.308333            24          24
# Tiffanyton            Suburban     28.510000           273          13
# Torresshire              Urban     24.207308          1820          26
# Travisville              Urban     27.220870           851          23
# Vickimouth               Urban     21.474667           195          15
# Webstertown           Suburban     29.721250           416          16
# West Alexis              Urban     19.523000           940          20
# West Brandy              Urban     24.157667           360          30
# West Brittanyton         Urban     25.436250           216          24
# West Dawnfurt            Urban     22.330345           986          29
# West Evan             Suburban     27.013333            48          12
# West Jefferyfurt         Urban     21.072857          1365          21
# West Kevintown           Rural     21.528571            35           7
# West Oscar               Urban     24.280000           319          29
# West Pamelaborough    Suburban     33.799286           378          14
# West Paulport         Suburban     33.278235            85          17
# West Peter               Urban     24.875484          1891          31
# West Sydneyhaven         Urban     22.368333          1260          18
# West Tony             Suburban     29.609474           323          19
# Williamchester        Suburban     34.278182           286          11
# Williamshire             Urban     26.990323          2170          31
# Wiseborough              Urban     22.676842          1045          19
# Yolandafurt              Urban     27.205500           140          20
# Zimmermanmouth           Urban     28.301667          1080          24
#
# [125 rows x 4 columns]

# %% [markdown]
# # Bubble Plot

# %%
# Labels
# plt.title("Pyber Ride Sharing Data (2016)")
# plt.ylabel("Average Fare($)")
# plt.xlabel("Total Number of Rides (Per City)")

# plt.scatter(ride_count, avg_fare, s=driver_count,facecolors="red",edgecolors="black")
# plt.show()

sns.lmplot(x='ride_id', y='fare', data=city_info,
          fit_reg=False
          )
plt.show()
